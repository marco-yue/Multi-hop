# %% [markdown]
# ### 01 packages

# %%
##########################################################################################
##########################################################################################

import networkx as nx

from shapely.geometry import Point,Polygon

import math

import random

##########################################################################################
##########################################################################################

import numpy as np

import pandas as pd

##########################################################################################
##########################################################################################

import matplotlib

import matplotlib.pyplot as plt

from matplotlib.ticker import MultipleLocator, FormatStrFormatter

##########################################################################################
##########################################################################################

from itertools import combinations

##########################################################################################
##########################################################################################

import copy

import os

# %% [markdown]
# ### 02 interior parameters

# %%
##########################################################################################
##########################################################################################

Base_speed=int(10000/60) # 10 KM per hour

##########################################################################################
##########################################################################################

alpha=1

speed=alpha*Base_speed

##########################################################################################
##########################################################################################

batch_interval=1

##########################################################################################
##########################################################################################

instance='01'

##########################################################################################
##########################################################################################

lambda_value = 20

pattern='uniform'#'centralized','uniform'

##########################################################################################
##########################################################################################

save_path="./03result/01Direct_Delivery/"+pattern+'_'+str(lambda_value)

if not os.path.exists(save_path):
    
    os.makedirs(save_path)

##########################################################################################
##########################################################################################

Nodes=np.load("./01network/"+instance+"/Nodes.npy")

Edges=np.load("./01network/"+instance+"/Edges.npy")

##########################################################################################
##########################################################################################

Road_Graph = nx.Graph()

for node in Nodes:
    
    node=tuple(node)
        
    Road_Graph.add_node(node)

for edge in Edges:
    
    node1=tuple(edge[0])
    
    node2=tuple(edge[1])
    
    Road_Graph.add_edge(node1, node2, weight=Point(node1).distance(Point(node2)))

# %%
def total_travel_distance(trajectory):
    
    total_distance = 0.0
    
    # Iterate through the trajectory and calculate the distance for each consecutive pair of coordinates
    
    for i in range(len(trajectory) - 1):
        
        total_distance += nx.shortest_path_length(Road_Graph, source=trajectory[i], target=trajectory[i + 1], weight='weight') 
    
    return total_distance

# %% [markdown]
# ### 04 Parcel-Courier assignment by EDD

# %%
##########################################################################################
##########################################################################################

parcel_df=pd.read_csv('./02data/01/instance_'+str(lambda_value)+'_'+pattern+'.csv')

parcel_df=parcel_df.drop(columns=['Unnamed: 0'])

##########################################################################################
##########################################################################################

parcel_df['pick_up']=parcel_df.apply(lambda x:tuple([round(float(y),2) for y in x.pick_up.replace('(','').replace(')','').split(',')]),axis=1)

parcel_df['drop_off']=parcel_df.apply(lambda x:tuple([round(float(y),2) for y in x.drop_off.replace('(','').replace(')','').split(',')]),axis=1)

##########################################################################################
##########################################################################################

parcel_df['courier_id']='None'

parcel_df['pick_up_time']=-float('inf')

parcel_df['drop_off_time']=-float('inf')

##########################################################################################
##########################################################################################

courier_df=pd.read_csv('./02data/'+instance+'/courier_instance.csv')

courier_df=courier_df.drop(columns=['Unnamed: 0'])

##########################################################################################
##########################################################################################

courier_schedules={}

for idx,row in courier_df.iterrows():
    
    courier_schedules[row.courier_id]={i:(row.x,row.y) for i in range(1,batch_interval+1,1)}
    
##########################################################################################
##########################################################################################

t=copy.copy(batch_interval)

##########################################################################################
##########################################################################################


dynamic_completions={}

dynamic_distances={}

while True:
    
    ##########################################################################################
    ##########################################################################################
    
    # 01 collect parcels
    
    collected_parcel=copy.copy(parcel_df.loc[(parcel_df.t_a<=t)&(parcel_df.courier_id=='None')])
    
    ##########################################################################################
    ##########################################################################################
    
    # select parcel with the earliest due time
    
    collected_parcel=collected_parcel.sort_values(by='t_dl', ascending=True)
    
    collected_parcel=collected_parcel.reset_index(drop=True)
    
    ##########################################################################################
    ##########################################################################################
    
    while not collected_parcel.empty:
        
        ##########################################################################################
        ##########################################################################################
        
        # select the parcel
    
        select_parcel=collected_parcel.iloc[0]
        
        parcel_id=select_parcel.parcel_id
        
        pick_up_point=select_parcel.pick_up
        
        drop_off_point=select_parcel.drop_off
        
        ##########################################################################################
        ##########################################################################################
        
        pick_up_times={}
        
        completion_times={}
        
        for courier_id,schedule in courier_schedules.items():
            
            courier_realse_time=list(schedule.keys())[-1]
            
            courier_realse_point=tuple(list(schedule.values())[-1])
            
            pick_up_distance=nx.shortest_path_length(Road_Graph, source=courier_realse_point, target=pick_up_point, weight='weight')
            
            drop_off_distance=nx.shortest_path_length(Road_Graph, source=pick_up_point, target=drop_off_point, weight='weight')
            
            pick_up_time=int(courier_realse_time+pick_up_distance/speed)
            
            completion_time=int(pick_up_time+drop_off_distance/speed)
            
            pick_up_times[courier_id]=pick_up_time
            
            completion_times[courier_id]=completion_time
            
        ##########################################################################################
        ##########################################################################################
            
        select_courier_id=min(completion_times, key=completion_times.get)
        
        select_courier_realse_time=list(courier_schedules[select_courier_id].keys())[-1]
        
        select_courier_realse_point=tuple(list(courier_schedules[select_courier_id].values())[-1])
        
        parcel_df.loc[(parcel_df['parcel_id']==parcel_id),'courier_id']=select_courier_id
        
        ##########################################################################################
        ##########################################################################################
        
        # update the schedule of couriers
        
        first_schedule=nx.shortest_path(Road_Graph, source=select_courier_realse_point, target=pick_up_point, weight='weight')
        
        second_schedule=nx.shortest_path(Road_Graph, source=pick_up_point, target=drop_off_point, weight='weight')
        
        for i in range(1,len(first_schedule),1):
            
            distance=nx.shortest_path_length(Road_Graph, source=first_schedule[i-1], target=first_schedule[i], weight='weight')
            
            select_courier_realse_time=select_courier_realse_time+int(distance/speed)
            
            courier_schedules[select_courier_id][select_courier_realse_time]=(first_schedule[i][0],first_schedule[i][1])
            
        parcel_df.loc[(parcel_df['parcel_id']==parcel_id),'pick_up_time']=select_courier_realse_time
            
        for j in range(1,len(second_schedule),1):
            
            distance=nx.shortest_path_length(Road_Graph, source=second_schedule[j-1], target=second_schedule[j], weight='weight')
            
            select_courier_realse_time=select_courier_realse_time+int(distance/speed)
            
            courier_schedules[select_courier_id][select_courier_realse_time]=(second_schedule[j][0],second_schedule[j][1])
            
        parcel_df.loc[(parcel_df['parcel_id']==parcel_id),'drop_off_time']=select_courier_realse_time
            
        ##########################################################################################
        ##########################################################################################
        
        # remove the selected parcel from the unassigned parcels
        
        collected_parcel = collected_parcel.drop(collected_parcel.index[0])
        
        collected_parcel = collected_parcel.reset_index(drop=True)
        
        
    ##########################################################################################
    ##########################################################################################
    
    # update the batch time
    
    for courier_id,schedules in courier_schedules.items():
            
        courier_realse_time=list(schedules.keys())[-1]

        courier_realse_point=tuple(list(schedules.values())[-1])

        if courier_realse_time==t:

            for i in range(1,batch_interval+1,1):

                 courier_schedules[courier_id][t+i]=courier_realse_point
                    
    ##########################################################################################
    ##########################################################################################
    
    t=int(t+batch_interval)
    
    if t%10==0:
            
        ttdis=0.0

        for schedules in courier_schedules.values():

            trajectory=list([v for k,v in schedules.items() if k<=t])

            ttdis+=total_travel_distance(trajectory)

        print("*"*100)

        print("Minute is ",t,", Number of completions is ",parcel_df.loc[(parcel_df.drop_off_time>=0)&(t>parcel_df.drop_off_time)].shape[0],\
              ", Total travel distance(KM) is ",round(ttdis/1000.0,2))
        
        dynamic_completions[t]=parcel_df.loc[(parcel_df.drop_off_time>=0)&(t>parcel_df.drop_off_time)].shape[0]
            
        dynamic_distances[t]=round(ttdis/1000.0,2)
    

    if parcel_df.loc[(parcel_df.courier_id=='None')].empty and t>parcel_df.drop_off_time.max():
    
        break
# Out:
# ****************************************************************************************************
# Minute is  10 , Number of completions is  0 , Total travel distance(KM) is  28.0
# ****************************************************************************************************
# Minute is  20 , Number of completions is  8 , Total travel distance(KM) is  84.0
# ****************************************************************************************************
# Minute is  30 , Number of completions is  12 , Total travel distance(KM) is  112.0
# ****************************************************************************************************
# Minute is  40 , Number of completions is  21 , Total travel distance(KM) is  168.0
# ****************************************************************************************************
# Minute is  50 , Number of completions is  27 , Total travel distance(KM) is  224.0
# ****************************************************************************************************
# Minute is  60 , Number of completions is  30 , Total travel distance(KM) is  252.0
# ****************************************************************************************************
# Minute is  70 , Number of completions is  38 , Total travel distance(KM) is  308.0
# ****************************************************************************************************
# Minute is  80 , Number of completions is  45 , Total travel distance(KM) is  364.0
# ****************************************************************************************************
# Minute is  90 , Number of completions is  51 , Total travel distance(KM) is  392.0
# ****************************************************************************************************
# Minute is  100 , Number of completions is  61 , Total travel distance(KM) is  448.0
# ****************************************************************************************************
# Minute is  110 , Number of completions is  69 , Total travel distance(KM) is  504.0
# ****************************************************************************************************
# Minute is  120 , Number of completions is  74 , Total travel distance(KM) is  532.0
# ****************************************************************************************************
# Minute is  130 , Number of completions is  86 , Total travel distance(KM) is  588.0
# ****************************************************************************************************
# Minute is  140 , Number of completions is  95 , Total travel distance(KM) is  644.0
# ****************************************************************************************************
# Minute is  150 , Number of completions is  96 , Total travel distance(KM) is  672.0
# ****************************************************************************************************
# Minute is  160 , Number of completions is  107 , Total travel distance(KM) is  728.0
# ****************************************************************************************************
# Minute is  170 , Number of completions is  117 , Total travel distance(KM) is  784.0
# ****************************************************************************************************
# Minute is  180 , Number of completions is  123 , Total travel distance(KM) is  812.0
# ****************************************************************************************************
# Minute is  190 , Number of completions is  129 , Total travel distance(KM) is  868.0
# ****************************************************************************************************
# Minute is  200 , Number of completions is  136 , Total travel distance(KM) is  924.0
# ****************************************************************************************************
# Minute is  210 , Number of completions is  144 , Total travel distance(KM) is  952.0
# ****************************************************************************************************
# Minute is  220 , Number of completions is  152 , Total travel distance(KM) is  1008.0
# ****************************************************************************************************
# Minute is  230 , Number of completions is  162 , Total travel distance(KM) is  1064.0
# ****************************************************************************************************
# Minute is  240 , Number of completions is  168 , Total travel distance(KM) is  1092.0
# ****************************************************************************************************
# Minute is  250 , Number of completions is  175 , Total travel distance(KM) is  1148.0
# ****************************************************************************************************
# Minute is  260 , Number of completions is  186 , Total travel distance(KM) is  1204.0
# ****************************************************************************************************
# Minute is  270 , Number of completions is  189 , Total travel distance(KM) is  1232.0
# ****************************************************************************************************
# Minute is  280 , Number of completions is  199 , Total travel distance(KM) is  1288.0
# ****************************************************************************************************
# Minute is  290 , Number of completions is  203 , Total travel distance(KM) is  1344.0
# ****************************************************************************************************
# Minute is  300 , Number of completions is  209 , Total travel distance(KM) is  1372.0
# ****************************************************************************************************
# Minute is  310 , Number of completions is  219 , Total travel distance(KM) is  1428.0
# ****************************************************************************************************
# Minute is  320 , Number of completions is  227 , Total travel distance(KM) is  1484.0
# ****************************************************************************************************
# Minute is  330 , Number of completions is  231 , Total travel distance(KM) is  1512.0
# ****************************************************************************************************
# Minute is  340 , Number of completions is  239 , Total travel distance(KM) is  1568.0
# ****************************************************************************************************
# Minute is  350 , Number of completions is  247 , Total travel distance(KM) is  1624.0
# ****************************************************************************************************
# Minute is  360 , Number of completions is  254 , Total travel distance(KM) is  1652.0
# ****************************************************************************************************
# Minute is  370 , Number of completions is  261 , Total travel distance(KM) is  1708.0
# ****************************************************************************************************
# Minute is  380 , Number of completions is  270 , Total travel distance(KM) is  1764.0
# ****************************************************************************************************
# Minute is  390 , Number of completions is  276 , Total travel distance(KM) is  1792.0
# ****************************************************************************************************
# Minute is  400 , Number of completions is  287 , Total travel distance(KM) is  1848.0
# ****************************************************************************************************
# Minute is  410 , Number of completions is  292 , Total travel distance(KM) is  1904.0
# ****************************************************************************************************
# Minute is  420 , Number of completions is  299 , Total travel distance(KM) is  1932.0
# ****************************************************************************************************
# Minute is  430 , Number of completions is  306 , Total travel distance(KM) is  1988.0
# ****************************************************************************************************
# Minute is  440 , Number of completions is  316 , Total travel distance(KM) is  2044.0
# ****************************************************************************************************
# Minute is  450 , Number of completions is  318 , Total travel distance(KM) is  2072.0
# ****************************************************************************************************
# Minute is  460 , Number of completions is  329 , Total travel distance(KM) is  2128.0
# ****************************************************************************************************
# Minute is  470 , Number of completions is  338 , Total travel distance(KM) is  2184.0
# ****************************************************************************************************
# Minute is  480 , Number of completions is  340 , Total travel distance(KM) is  2212.0
# ****************************************************************************************************
# Minute is  490 , Number of completions is  350 , Total travel distance(KM) is  2268.0
# ****************************************************************************************************
# Minute is  500 , Number of completions is  363 , Total travel distance(KM) is  2324.0
# ****************************************************************************************************
# Minute is  510 , Number of completions is  365 , Total travel distance(KM) is  2352.0
# ****************************************************************************************************
# Minute is  520 , Number of completions is  372 , Total travel distance(KM) is  2408.0
# ****************************************************************************************************
# Minute is  530 , Number of completions is  384 , Total travel distance(KM) is  2464.0
# ****************************************************************************************************
# Minute is  540 , Number of completions is  387 , Total travel distance(KM) is  2492.0
# ****************************************************************************************************
# Minute is  550 , Number of completions is  396 , Total travel distance(KM) is  2548.0
# ****************************************************************************************************
# Minute is  560 , Number of completions is  403 , Total travel distance(KM) is  2604.0
# ****************************************************************************************************
# Minute is  570 , Number of completions is  408 , Total travel distance(KM) is  2632.0
# ****************************************************************************************************
# Minute is  580 , Number of completions is  417 , Total travel distance(KM) is  2688.0
# ****************************************************************************************************
# Minute is  590 , Number of completions is  430 , Total travel distance(KM) is  2744.0
# ****************************************************************************************************
# Minute is  600 , Number of completions is  436 , Total travel distance(KM) is  2772.0
# ****************************************************************************************************
# Minute is  610 , Number of completions is  445 , Total travel distance(KM) is  2828.0
# ****************************************************************************************************
# Minute is  620 , Number of completions is  453 , Total travel distance(KM) is  2884.0
# ****************************************************************************************************
# Minute is  630 , Number of completions is  455 , Total travel distance(KM) is  2912.0
# ****************************************************************************************************
# Minute is  640 , Number of completions is  468 , Total travel distance(KM) is  2968.0
# ****************************************************************************************************
# Minute is  650 , Number of completions is  476 , Total travel distance(KM) is  3024.0
# ****************************************************************************************************
# Minute is  660 , Number of completions is  480 , Total travel distance(KM) is  3052.0
# ****************************************************************************************************
# Minute is  670 , Number of completions is  493 , Total travel distance(KM) is  3108.0
# ****************************************************************************************************
# Minute is  680 , Number of completions is  500 , Total travel distance(KM) is  3164.0
# ****************************************************************************************************
# Minute is  690 , Number of completions is  505 , Total travel distance(KM) is  3192.0
# ****************************************************************************************************
# Minute is  700 , Number of completions is  511 , Total travel distance(KM) is  3248.0
# ****************************************************************************************************
# Minute is  710 , Number of completions is  522 , Total travel distance(KM) is  3304.0
# ****************************************************************************************************
# Minute is  720 , Number of completions is  528 , Total travel distance(KM) is  3332.0
# ****************************************************************************************************
# Minute is  730 , Number of completions is  535 , Total travel distance(KM) is  3388.0
# ****************************************************************************************************
# Minute is  740 , Number of completions is  541 , Total travel distance(KM) is  3444.0
# ****************************************************************************************************
# Minute is  750 , Number of completions is  549 , Total travel distance(KM) is  3472.0
# ****************************************************************************************************
# Minute is  760 , Number of completions is  555 , Total travel distance(KM) is  3528.0
# ****************************************************************************************************
# Minute is  770 , Number of completions is  564 , Total travel distance(KM) is  3584.0
# ****************************************************************************************************
# Minute is  780 , Number of completions is  567 , Total travel distance(KM) is  3612.0
# ****************************************************************************************************
# Minute is  790 , Number of completions is  576 , Total travel distance(KM) is  3668.0
# ****************************************************************************************************
# Minute is  800 , Number of completions is  587 , Total travel distance(KM) is  3724.0
# ****************************************************************************************************
# Minute is  810 , Number of completions is  591 , Total travel distance(KM) is  3752.0
# ****************************************************************************************************
# Minute is  820 , Number of completions is  602 , Total travel distance(KM) is  3808.0
# ****************************************************************************************************
# Minute is  830 , Number of completions is  610 , Total travel distance(KM) is  3864.0
# ****************************************************************************************************
# Minute is  840 , Number of completions is  614 , Total travel distance(KM) is  3892.0
# ****************************************************************************************************
# Minute is  850 , Number of completions is  621 , Total travel distance(KM) is  3948.0
# ****************************************************************************************************
# Minute is  860 , Number of completions is  632 , Total travel distance(KM) is  4004.0
# ****************************************************************************************************
# Minute is  870 , Number of completions is  635 , Total travel distance(KM) is  4032.0
# ****************************************************************************************************
# Minute is  880 , Number of completions is  645 , Total travel distance(KM) is  4088.0
# ****************************************************************************************************
# Minute is  890 , Number of completions is  652 , Total travel distance(KM) is  4144.0
# ****************************************************************************************************
# Minute is  900 , Number of completions is  656 , Total travel distance(KM) is  4172.0
# ****************************************************************************************************
# Minute is  910 , Number of completions is  668 , Total travel distance(KM) is  4228.0
# ****************************************************************************************************
# Minute is  920 , Number of completions is  678 , Total travel distance(KM) is  4284.0
# ****************************************************************************************************
# Minute is  930 , Number of completions is  684 , Total travel distance(KM) is  4312.0
# ****************************************************************************************************
# Minute is  940 , Number of completions is  694 , Total travel distance(KM) is  4368.0
# ****************************************************************************************************
# Minute is  950 , Number of completions is  702 , Total travel distance(KM) is  4424.0
# ****************************************************************************************************
# Minute is  960 , Number of completions is  710 , Total travel distance(KM) is  4452.0
# ****************************************************************************************************
# Minute is  970 , Number of completions is  718 , Total travel distance(KM) is  4508.0
# ****************************************************************************************************
# Minute is  980 , Number of completions is  727 , Total travel distance(KM) is  4564.0
# ****************************************************************************************************
# Minute is  990 , Number of completions is  736 , Total travel distance(KM) is  4592.0
# ****************************************************************************************************
# Minute is  1000 , Number of completions is  742 , Total travel distance(KM) is  4648.0
# ****************************************************************************************************
# Minute is  1010 , Number of completions is  749 , Total travel distance(KM) is  4704.0
# ****************************************************************************************************
# Minute is  1020 , Number of completions is  755 , Total travel distance(KM) is  4732.0
# ****************************************************************************************************
# Minute is  1030 , Number of completions is  763 , Total travel distance(KM) is  4788.0
# ****************************************************************************************************
# Minute is  1040 , Number of completions is  773 , Total travel distance(KM) is  4844.0
# ****************************************************************************************************
# Minute is  1050 , Number of completions is  776 , Total travel distance(KM) is  4872.0
# ****************************************************************************************************
# Minute is  1060 , Number of completions is  781 , Total travel distance(KM) is  4928.0
# ****************************************************************************************************
# Minute is  1070 , Number of completions is  794 , Total travel distance(KM) is  4984.0
# ****************************************************************************************************
# Minute is  1080 , Number of completions is  797 , Total travel distance(KM) is  5012.0
# ****************************************************************************************************
# Minute is  1090 , Number of completions is  804 , Total travel distance(KM) is  5068.0
# ****************************************************************************************************
# Minute is  1100 , Number of completions is  813 , Total travel distance(KM) is  5124.0
# ****************************************************************************************************
# Minute is  1110 , Number of completions is  820 , Total travel distance(KM) is  5152.0
# ****************************************************************************************************
# Minute is  1120 , Number of completions is  828 , Total travel distance(KM) is  5208.0
# ****************************************************************************************************
# Minute is  1130 , Number of completions is  835 , Total travel distance(KM) is  5264.0
# ****************************************************************************************************
# Minute is  1140 , Number of completions is  840 , Total travel distance(KM) is  5292.0
# ****************************************************************************************************
# Minute is  1150 , Number of completions is  848 , Total travel distance(KM) is  5348.0
# ****************************************************************************************************
# Minute is  1160 , Number of completions is  856 , Total travel distance(KM) is  5404.0
# ****************************************************************************************************
# Minute is  1170 , Number of completions is  862 , Total travel distance(KM) is  5432.0
# ****************************************************************************************************
# Minute is  1180 , Number of completions is  871 , Total travel distance(KM) is  5488.0
# ****************************************************************************************************
# Minute is  1190 , Number of completions is  881 , Total travel distance(KM) is  5544.0
# ****************************************************************************************************
# Minute is  1200 , Number of completions is  885 , Total travel distance(KM) is  5572.0
# ****************************************************************************************************
# Minute is  1210 , Number of completions is  892 , Total travel distance(KM) is  5628.0
# ****************************************************************************************************
# Minute is  1220 , Number of completions is  903 , Total travel distance(KM) is  5684.0
# ****************************************************************************************************
# Minute is  1230 , Number of completions is  909 , Total travel distance(KM) is  5712.0
# ****************************************************************************************************
# Minute is  1240 , Number of completions is  918 , Total travel distance(KM) is  5768.0
# ****************************************************************************************************
# Minute is  1250 , Number of completions is  926 , Total travel distance(KM) is  5824.0
# ****************************************************************************************************
# Minute is  1260 , Number of completions is  930 , Total travel distance(KM) is  5852.0
# ****************************************************************************************************
# Minute is  1270 , Number of completions is  940 , Total travel distance(KM) is  5908.0
# ****************************************************************************************************
# Minute is  1280 , Number of completions is  950 , Total travel distance(KM) is  5964.0
# ****************************************************************************************************
# Minute is  1290 , Number of completions is  957 , Total travel distance(KM) is  5992.0
# ****************************************************************************************************
# Minute is  1300 , Number of completions is  965 , Total travel distance(KM) is  6047.0
# ****************************************************************************************************
# Minute is  1310 , Number of completions is  976 , Total travel distance(KM) is  6101.0
# ****************************************************************************************************
# Minute is  1320 , Number of completions is  981 , Total travel distance(KM) is  6123.0
# ****************************************************************************************************
# Minute is  1330 , Number of completions is  988 , Total travel distance(KM) is  6155.0
# ****************************************************************************************************
# Minute is  1340 , Number of completions is  993 , Total travel distance(KM) is  6174.0
# ****************************************************************************************************
# Minute is  1350 , Number of completions is  993 , Total travel distance(KM) is  6181.0
# ****************************************************************************************************
# Minute is  1360 , Number of completions is  998 , Total travel distance(KM) is  6193.0
# ****************************************************************************************************
# Minute is  1370 , Number of completions is  1000 , Total travel distance(KM) is  6197.0

# %% [markdown]
# ### 05 save results

# %%
##########################################################################################
##########################################################################################

# 01 save parcel

parcel_df.to_csv(save_path+"/parcel_df_"+str(alpha)+"_"+str(batch_interval)+".csv")

##########################################################################################
##########################################################################################

def generate_trajectory(origin, destination):
    
    # Calculate the total distance
    
    distance = Point(destination).distance(Point(origin))
    
    # Calculate total time
    total_time = distance / speed
    
    # Calculate the number of intervals
    intervals = int(np.floor(total_time))
    
    # Create an array to hold the trajectory
    trajectory = np.zeros((intervals+1, 2))  # Assuming 2D coordinates
    
    for i in range(intervals+1):
        # Interpolate the position for each time interval
        alpha = i / intervals
        trajectory[i] = np.array(origin) * (1 - alpha) + np.array(destination) * alpha

    return trajectory

##########################################################################################
##########################################################################################

# 02 complete trajectory

for courier_id,schedules in courier_schedules.items():
    
    completed_schedules=copy.copy(schedules)
    
    stamps=list(schedules.keys())
    
    nodes=list(schedules.values())
    
    for i in range(1,len(stamps),1):
        
        pre_t,t=stamps[i-1],stamps[i]
        
        pre_node,node=nodes[i-1],nodes[i]
        
        if t>pre_t+1:
            
            trajectory=generate_trajectory(pre_node, node)
            
            for j in range(1,len(trajectory)-1,1):
                
                insert_node=tuple([round(x,2) for x in trajectory[j]])
                
                completed_schedules[int(pre_t+j)]=insert_node
                
    completed_schedules = dict(sorted(completed_schedules.items()))
    
    courier_schedules[courier_id]=completed_schedules
            
##########################################################################################
##########################################################################################

np.save(save_path+"/courier_schedules_"+str(alpha)+"_"+str(batch_interval),courier_schedules)

np.save(save_path+"/dynamic_completions_"+str(alpha)+"_"+str(batch_interval),dynamic_completions)

np.save(save_path+"/dynamic_distances_"+str(alpha)+"_"+str(batch_interval),dynamic_distances)

# %%
parcel_df
# Out:
#     parcel_id  t_a              pick_up             drop_off   h1   h2  \
# 0          p1    0     (1000.0, 3464.1)     (2500.0, 866.03)  H19   H8
# 1          p2    0     (500.0, 2598.08)    (-1500.0, 866.03)  H18   H6
# 2          p3    0   (-1000.0, 1732.05)   (3500.0, -2598.08)   H6  H10
# 3          p4    0    (3000.0, 1732.05)  (-2000.0, -1732.05)   H8   H5
# 4          p5    0    (500.0, -2598.08)   (-3500.0, -866.03)  H12  H14
# ..        ...  ...                  ...                  ...  ...  ...
# 995      p996   49  (-4000.0, -1732.05)        (1000.0, 0.0)  H14   H2
# 996      p997   49      (500.0, 866.03)       (2000.0, -0.0)   H1   H2
# 997      p998   49     (1000.0, 3464.1)  (-4000.0, -1732.05)  H18  H14
# 998      p999   49      (500.0, 866.03)       (0.0, -3464.1)   H7  H12
# 999     p1000   49  (-4000.0, -1732.05)    (1000.0, 1732.05)  H14   H7
#
#      shortest_distance  t_dl courier_id  pick_up_time  drop_off_time
# 0                 2999   127        c19          13.0           31.0
# 1                 2999   133         c6          13.0           31.0
# 2                 7000   336         c6          37.0           79.0
# 3                 6999   302        c12          49.0           91.0
# 4                 4999   255         c2          19.0           49.0
# ..                 ...   ...        ...           ...            ...
# 995               5999   290        c15        1315.0         1351.0
# 996               2000   126         c7        1297.0         1309.0
# 997               7999   505        c25        1321.0         1369.0
# 998               5000   223        c23        1303.0         1333.0
# 999               6999   411        c14        1327.0         1369.0
#
# [1000 rows x 11 columns]
